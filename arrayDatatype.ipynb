# %%
import numpy as np

# %% [markdown]
# ## Data Type

# %%
arr = np.array([1, 2, 3, 4], dtype='i4')

print(arr)
print(arr.dtype)
# Out:
# [1 2 3 4]
# int32

# %%
arr = np.array([1, 0, 3, -1])

newarr = arr.astype(bool)

print(newarr)
print(newarr.dtype)
# Out:
# [ True False  True  True]
# bool
